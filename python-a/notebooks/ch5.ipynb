# %% [markdown]
# # פרק 5: ביצוע חוזר — for ו-while
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# ## שאלה 1 — מצאו את הטעות
# הקוד הבא נתקע בלולאה אינסופית. מצאו את הבעיה ותקנו אותה (זהירות בהרצה!):
# ```python
# i = 1
# while i <= 5:
#     print(i)
# ```

# %%
i = 1
while i <= 5:
    print(i)
    # מה חסר כאן?

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו תכנית שמדפיסה את כל המספרים המתחלקים ב-5, מ-5 עד 30 (כולל), על אותה שורה.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# כתבו תכנית שקולטת 10 ציונים בלולאת for, ומדפיסה כמה מהם היו מעל 80. אחר כך כתבו אותה תכנית שוב באמצעות while.

# %%
# פתרון עם for

# %%
# פתרון עם while

# %% [markdown]
# ---
# בהצלחה! 🎉
