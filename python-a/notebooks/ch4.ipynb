# %% [markdown]
# # פרק 4: ביצוע מותנה — if / elif / else
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# ## שאלה 1 — מצאו את הטעות
# בקוד הבא יש טעות לוגית - הוא תמיד מדפיס "Prize!" גם לציונים נמוכים. מצאו ותקנו:
# ```python
# grade = int(input("Grade: "))
# if grade > 90 or grade <= 100:
#     print("Prize!")
# else:
#     print("No prize")
# ```

# %%
# תקנו את הקוד כאן והריצו לבדיקה
grade = int(input("Grade: "))
if grade > 90 or grade <= 100:
    print("Prize!")
else:
    print("No prize")

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו תכנית שקולטת גיל, ומדפיסה "ילד/ה" עד גיל 12, "נער/ה" מגיל 13 עד 17, ו"בוגר/ת" מגיל 18 ומעלה.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# כתבו תכנית שקולטת מספר ומדפיסה "boom" אם הוא מתחלק ב-7 או מכיל את הספרה 7 — אחרת מדפיסה את המספר עצמו.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ---
# בהצלחה! 🎉
