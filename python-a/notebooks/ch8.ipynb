# %% [markdown]
# # פרק 8: פונקציות עם פרמטרים
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# ## שאלה 1 — מצאו את הטעות
# הקוד אמור לספור קריאות לפונקציה, אבל counter נשאר 0 (ואף גורם לשגיאה). מה חסר?
# ```python
# counter = 0
#
# def log_call():
#     counter = counter + 1
#
# log_call()
# log_call()
# print(counter)
# ```

# %%
counter = 0

def log_call():
    counter = counter + 1  # מה חסר כדי שזה יעבוד?

log_call()
log_call()
print(counter)

# %% [markdown]
# ## שאלה 2 — כתבו פונקציה
# כתבו פונקציה בשם is_even שמקבלת מספר, ומדפיסה אם הוא זוגי או אי-זוגי.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 3 — כתבו פונקציה
# כתבו פונקציה בשם average שמקבלת שני מספרים, ומדפיסה את הממוצע ביניהם.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 4 — פרויקט קטן
# כתבו 4 פונקציות: add(a,b), subtract(a,b), multiply(a,b), divide(a,b). אחר כך כתבו תפריט שקולט בחירה ושני מספרים, וקורא לפונקציה המתאימה.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ---
# בהצלחה! 🎉
