# %% [markdown]
# # פרק 6: מחרוזות (str)
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# ## שאלה 1 — עקבו אחר הקוד
# נחשו לפני ההרצה:
# ```python
# title = "Python is fun!"
# print(title[3])
# print(title[-1])
# print(title[::2])
# print(len(title))
# ```

# %%
title = "Python is fun!"
print(title[3])
print(title[-1])
print(title[::2])
print(len(title))

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו תכנית שקולטת מילה, ומדפיסה אותה הפוכה.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# כתבו תכנית שקולטת שם פרטי, ומדפיסה אותו עם כוכבית בין כל שתי אותיות — למשל "Emma" יהפוך ל-"E*m*m*a".

# %%
# הקוד שלכם כאן

# %% [markdown]
# ---
# בהצלחה! 🎉
