# %% [markdown]
# # פרק 7: בעיות אלגוריתמיות
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# ## שאלה 1 — מצאו את הטעות
# הפעולה נועדה לצבור סכום של 5 מספרים אך לא עושה זאת נכון. מצאו ותקנו:
# ```python
# def sum_numbers():
#     total = 0
#     for i in range(5):
#         num = int(input("Number: "))
#         total = num
#     print(total)
# ```

# %%
def sum_numbers():
    total = 0
    for i in range(5):
        num = int(input("Number: "))
        total = num  # תקנו כאן
    print(total)

sum_numbers()

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו תכנית שמדמה 20 הטלות קובייה (עם random.randint), וסופרת כמה פעמים יצא המספר 6.

# %%
import random

# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# כתבו תכנית שקולטת 8 מספרים, ומדפיסה את הקטן ביותר מביניהם.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 4 — פרויקט קטן
# כתבו משחק "נחשו את המספר": המחשב בוחר מספר אקראי בין 1 ל-20, השחקן/ית מנחש/ת עד שמצליח/ה, והתכנית מדפיסה "too high"/"too low" בכל ניחוש שגוי ובסוף את מספר הניסיונות.

# %%
import random

# הקוד שלכם כאן

# %% [markdown]
# ---
# בהצלחה! 🎉
