# %% [markdown]
# # פרק 2: תנועה ומבוא לגרפיקה — Turtle
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# **שימו לב:** גרפיקת Turtle לא תמיד תוצג בתוך Colab. אם התמונה לא נפתחת, פתחו את השאלות האלה ב-[OneCompiler](https://onecompiler.com/turtle) במקום.

# %% [markdown]
# ## שאלה 1 — כתבו תוכנית
# כתבו תכנית שמציירת משולש שווה-צלעות (רמז: זווית פנייה של 360/3 מעלות).

# %%
import turtle

wn = turtle.Screen()
player = turtle.Turtle()

# הקוד שלכם כאן

turtle.mainloop()

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# שנו את התכנית כך שתצייר מצולע משוכלל בעל 6 צלעות.

# %%
import turtle

wn = turtle.Screen()
player = turtle.Turtle()

# הקוד שלכם כאן

turtle.mainloop()

# %% [markdown]
# ## שאלה 3 — אתגר
# צרו תכנית שמציירת 4 ריבועים בגדלים שונים (10, 20, 30, 40) הנפתחים מאותה נקודת פינה — כמו בשאלה 2 בדף העבודה באתר.

# %%
import turtle

wn = turtle.Screen()
player = turtle.Turtle()

# הקוד שלכם כאן

turtle.mainloop()

# %% [markdown]
# ## שאלה 4 — פרויקט קטן
# ציירו בית פשוט: ריבוע לגוף הבית ומשולש לגג מעליו.

# %%
import turtle

wn = turtle.Screen()
player = turtle.Turtle()

# הקוד שלכם כאן

turtle.mainloop()

# %% [markdown]
# ---
# בהצלחה! 🎉
