# %% [markdown]
# # פרק 1: מבוא ל-Python
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# ## שאלה 1 — עקבו אחר הקוד
# כתבו בתא הבא בעצמכם (כהערה) מה תהיה תוצאת ההרצה של הקוד הבא, ואז הריצו כדי לבדוק:
# ```python
# print("Step 1")
# # print("this should not be printed")
# print("Step 2", "done")
# ```

# %%
# הנחה שלכם:
# ___________

print("Step 1")
# print("this should not be printed")
print("Step 2", "done")

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו תכנית שמדפיסה בשלוש שורות נפרדות: את שמכם, את הכיתה שלכם, ותחביב שאתם אוהבים.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 3 — כתבו פונקציה
# כתבו פונקציה בשם my_intro שמדפיסה משפט הצגה עצמית קצר, וזמנו אותה כדי שתרוץ. הוסיפו הערה (עם #) מעל הפונקציה שמסבירה מה היא עושה.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ---
# בהצלחה! 🎉
