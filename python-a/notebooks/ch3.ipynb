# %% [markdown]
# # פרק 3: משתנים, קלט/פלט וחישובים
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# ## שאלה 1 — עקבו אחר הקוד
# לפני שאתם מריצים, נחשו מה יודפס:
# ```python
# num = 4567
# print(num // 100)
# print(num % 100)
# ```

# %%
num = 4567
print(num // 100)
print(num % 100)

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו תכנית שקולטת שני מספרים שלמים מהמשתמש, ומדפיסה את הסכום, ההפרש והמכפלה שלהם.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# כתבו תכנית שקולטת מספר תלת-ספרתי, ומדפיסה בנפרד את ספרת המאות, ספרת העשרות וספרת האחדות שלו.

# %%
# הקוד שלכם כאן

# %% [markdown]
# ---
# בהצלחה! 🎉
