# %% [markdown]
# # פרק 9: תכנות מונחה אירועים
# ### מחברת תרגול — Python חלק א׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
# ---

# %% [markdown]
# **שימו לב:** הפרק הזה משלב Turtle עם אירועי עכבר/מקלדת — מומלץ לתרגל אותו ב-[Trinket](https://trinket.io/features/turtle_graphics) שבו לחיצות עכבר ומקלדת פועלות בדפדפן.

# %% [markdown]
# ## שאלה 1 — כתבו תוכנית
# כתבו תכנית שמציירת ריבוע בכל מקום שלוחצים עליו עם העכבר, כאשר גודל הריבוע גדל ב-5 בכל לחיצה.

# %%
import turtle

# הקוד שלכם כאן

turtle.mainloop()

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו תכנית שמזיזה את הדמות עם ארבעת המקשים (למעלה, למטה, ימינה, שמאלה).

# %%
import turtle

# הקוד שלכם כאן

turtle.mainloop()

# %% [markdown]
# ## שאלה 3 — אתגר
# שלבו לחיצת עכבר עם צבעים לסירוגין — לחיצה ראשונה מציירת באדום, השנייה בכחול, וכן הלאה.

# %%
import turtle

# הקוד שלכם כאן

turtle.mainloop()

# %% [markdown]
# ---
# כל הכבוד על סיום מסלול Python חלק א׳! 🎉
