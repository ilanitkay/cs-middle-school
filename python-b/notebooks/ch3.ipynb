# %% [markdown]
# # פרק 3: מחרוזות (str)
# ### מחברת תרגול — Python חלק ב׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
#
# **כדי לשמור את העבודה:** File ← Save a copy in Drive — כך נוצר עותק אישי ב-Google Drive שלכם, וכל שינוי נשמר אוטומטית.
# ---

# %% [markdown]
# ## שאלה 1 — כתבו תוכנית
# קלטו מחרוזת מהמשתמש והדפיסו כמה אותיות "e" יש בה — פעם אחת עם לולאה על התווים, ופעם אחת עם `count`.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו פונקציה `is_palindrome(word)` שמחזירה `True` אם המילה נקראת אותו דבר משני הכיוונים. השתמשו ב-slicing.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# קלטו שם מלא (שם פרטי רווח שם משפחה). הדפיסו את ראשי התיבות, למשל "Dana Levi" ← "D.L."

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 4 — מצאו את הטעות
# הקוד אמור להפוך את המחרוזת לאותיות גדולות, אבל ההדפסה מציגה "hello". תקנו.

# %%
s = "hello"

s.upper()

print(s)
