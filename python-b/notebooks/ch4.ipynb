# %% [markdown]
# # פרק 4: רשימות (list)
# ### מחברת תרגול — Python חלק ב׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
#
# **כדי לשמור את העבודה:** File ← Save a copy in Drive — כך נוצר עותק אישי ב-Google Drive שלכם, וכל שינוי נשמר אוטומטית.
# ---

# %% [markdown]
# ## שאלה 1 — כתבו תוכנית
# קלטו 5 מספרים מהמשתמש לתוך רשימה (בעזרת לולאה ו-`append`), והדפיסו את הסכום והממוצע.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# נתונה רשימה `names`. כתבו קוד שסופר כמה שמות ברשימה מתחילים באות "A".

# %%
names = ["Ann", "Bob", "Amy", "Dan"]

# המשיכו מכאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# כתבו פונקציה `above_average(nums)` שמחזירה רשימה חדשה עם כל המספרים שגדולים מהממוצע של `nums`.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 4 — מצאו את הטעות
# הקוד אמור לסדר את הרשימה ולהדפיס אותה, אבל מודפס `None`. תקנו.

# %%
nums = [3, 1, 2]

nums = nums.sort()

print(nums)
