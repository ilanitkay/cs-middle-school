# %% [markdown]
# # פרק 6: עבודה עם קבצים
# ### מחברת תרגול — Python חלק ב׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
#
# **כדי לשמור את העבודה:** File ← Save a copy in Drive — כך נוצר עותק אישי ב-Google Drive שלכם, וכל שינוי נשמר אוטומטית.
# ---

# %% [markdown]
# ### הכנה — יצירת קבצי דוגמה
# ב-Colab אין קבצים מוכנים. הריצו את התא הבא **פעם אחת** כדי ליצור את הקבצים `names.txt` ו-`grades.txt` לתרגול.

# %%
with open("names.txt", "w") as f:

    f.write("Dana\nYoav\nMaya\nOmer\nNoa\n")



with open("grades.txt", "w") as f:

    f.write("85\n52\n90\n47\n73\n68\n100\n55\n")



print("Files created.")

# %% [markdown]
# ## שאלה 1 — כתבו תוכנית
# הקובץ `names.txt` מכיל שם בכל שורה. כתבו קוד שמדפיס כמה שמות יש בקובץ.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# קלטו מהמשתמש שמות עד שמקלידים מחרוזת ריקה, ושמרו כל שם בשורה נפרדת בקובץ `guests.txt`.
# לאחר מכן פתחו את `guests.txt` לקריאה והדפיסו את תוכנו כדי לוודא.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 3 — פרויקט מסכם: ניתוח ציונים
# הקובץ `grades.txt` מכיל ציון (מספר שלם) בכל שורה. כתבו תכנית ש:
# 1. קוראת את כל הציונים לרשימה
# 2. מחשבת ממוצע, ציון מקסימלי וציון מינימלי
# 3. סופרת כמה תלמידים מתחת ל-60
# 4. כותבת את הסיכום לקובץ חדש `summary.txt`

# %%
# כתבו את הקוד כאן
