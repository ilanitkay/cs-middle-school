# %% [markdown]
# # פרק 2: פונקציות
# ### מחברת תרגול — Python חלק ב׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
#
# **כדי לשמור את העבודה:** File ← Save a copy in Drive — כך נוצר עותק אישי ב-Google Drive שלכם, וכל שינוי נשמר אוטומטית.
# ---

# %% [markdown]
# ## שאלה 1 — מצאו את הטעות
# הפונקציה אמורה להחזיר את הגדול מבין שני מספרים, אבל `print(bigger(4, 9))` מדפיס `None`. תקנו.

# %%
def bigger(a, b):

    if a > b:

        print(a)

    else:

        print(b)



print(bigger(4, 9))

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו פונקציה `is_even(n)` שמחזירה `True` אם `n` זוגי ו-`False` אחרת.
# השתמשו בה כדי להדפיס את כל המספרים הזוגיים מ-1 עד 20.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# כתבו פונקציה `average(a, b, c)` שמחזירה את הממוצע של שלושה מספרים.
# קראו לה עם 3 מספרים שהמשתמש מקליד, והדפיסו את התוצאה.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 4 — פירוק לתת-משימות
# כתבו פונקציה `reverse_word(word)` שמחזירה מחרוזת הפוכה, ופונקציה `is_palindrome(word)` שמשתמשת בה ומחזירה `True`/`False`.
# הדפיסו בדיקה עבור "level" ועבור "python".

# %%
# כתבו את הקוד כאן
