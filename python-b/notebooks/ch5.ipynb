# %% [markdown]
# # פרק 5: מבני נתונים — tuple, set ותור
# ### מחברת תרגול — Python חלק ב׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
#
# **כדי לשמור את העבודה:** File ← Save a copy in Drive — כך נוצר עותק אישי ב-Google Drive שלכם, וכל שינוי נשמר אוטומטית.
# ---

# %% [markdown]
# ## שאלה 1 — כתבו תוכנית
# קלטו משפט מהמשתמש והדפיסו כמה אותיות שונות יש בו (התעלמו מרווחים). השתמשו ב-`set`.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 2 — פרויקט קטן: תור הדפסה
# המשתמש מקליד שמות קבצים עד שמקליד מחרוזת ריקה — כל שם נכנס לתור.
# אחר כך התכנית מדפיסה "Printing: <name>" עבור כל קובץ, לפי סדר ההכנסה, עד שהתור מתרוקן.

# %%
queue = []

# המשיכו מכאן

# %% [markdown]
# ## שאלה 3 — בדקו את עצמכם
# הריצו את הקוד. מה קורה בשורה האחרונה, ולמה? כתבו את ההסבר כהערה, ואז תקנו כך שהתכנית לא תקרוס.

# %%
point = (3, 5)

print(point[0])

point[0] = 9
