# %% [markdown]
# # פרק 1: ביצוע חוזר — לולאות
# ### מחברת תרגול — Python חלק ב׳ | מדעי המחשב לחטיבת הביניים | אילנית קיי
#
# כתבו את הפתרון שלכם בתא הקוד שאחרי כל שאלה, והריצו אותו (Shift+Enter) כדי לבדוק את התוצאה.
#
# **כדי לשמור את העבודה:** File ← Save a copy in Drive — כך נוצר עותק אישי ב-Google Drive שלכם, וכל שינוי נשמר אוטומטית.
# ---

# %% [markdown]
# ## שאלה 1 — כתבו תוכנית
# כתבו לולאה שמדפיסה את כל המספרים הזוגיים בין 2 ל-20 (כולל).

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 2 — כתבו תוכנית
# כתבו תכנית שקולטת מספרים מהמשתמש עד שמקלידים -1, ובסוף מדפיסה כמה מספרים חיוביים הוקלדו.

# %%
# כתבו את הקוד כאן

# %% [markdown]
# ## שאלה 3 — כתבו תוכנית
# כתבו תכנית שמגרילה מספר סודי בין 1 ל-50 (`random.randint(1, 50)`), וחוזרת לבקש ניחוש מהמשתמש עד שהוא צודק.
# בכל ניחוש הדפיסו "Too high" או "Too low", ובסוף כמה ניחושים נדרשו.

# %%
import random



secret = random.randint(1, 50)

# המשיכו מכאן

# %% [markdown]
# ## שאלה 4 — מצאו את הטעות
# הקוד אמור להדפיס 1 עד 5, אבל הוא לא נגמר. תקנו אותו.

# %%
i = 1

while i <= 5:

    print(i)

    # מה חסר כאן?
